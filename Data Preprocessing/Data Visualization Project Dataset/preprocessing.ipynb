# %%
import pandas as pd

# Load the Excel files
df2 = pd.read_excel('/Users/srushtitikekar/Downloads/Data Visualization Project Dataset/DEMO_H_output_file.xlsx')
df1 = pd.read_excel('/Users/srushtitikekar/Downloads/Data Visualization Project Dataset/NHANES_age_prediction.xlsx')

# Select only the columns you want to add from df2 (including 'seqn' for merging)

# RIDRETH3, DMDBORN4 , DMDCITZN,DMDEDUC3, DMDEDUC2,DMDMARTL,RIDEXPRG]
columns_to_add = ['SEQN','RIDRETH3', 'DMDBORN4' , 'DMDCITZN','DMDEDUC3', 'DMDEDUC2','DMDMARTL','RIDEXPRG']  # Replace with actual column names
df2_subset = df2[columns_to_add]

# Merge the files based on the unique 'seqn' column
merged_df = pd.merge(df1, df2_subset, on='SEQN', how='left')

# Save the result to a new Excel file
#merged_df.to_excel('merged_output.xlsx', index=False)

print("Columns from file1 have been mapped to file2 based on 'seqn' and saved to 'merged_output.xlsx'")
# Out:
# Columns from file1 have been mapped to file2 based on 'seqn' and saved to 'merged_output.xlsx'

# %%
merged_df
# Out:
#        SEQN age_group  RIDAGEYR  RIAGENDR  PAQ605  BMXBMI  LBXGLU  DIQ010  \
# 0     73564     Adult        61         2       2    35.7     110       2
# 1     73568     Adult        26         2       2    20.3      89       2
# 2     73576     Adult        16         1       2    23.2      89       2
# 3     73577     Adult        32         1       2    28.9     104       2
# 4     73580     Adult        38         2       1    35.9     103       2
# ...     ...       ...       ...       ...     ...     ...     ...     ...
# 2273  83711     Adult        38         2       2    33.5     100       2
# 2274  83712     Adult        61         1       2    30.0      93       2
# 2275  83713     Adult        34         1       2    23.7     103       2
# 2276  83718     Adult        60         2       2    27.4      90       2
# 2277  83727     Adult        26         1       2    24.5     108       2
#
#       LBXGLT  LBXIN CardioVascular  RIDRETH3  DMDBORN4  DMDCITZN  DMDEDUC3  \
# ...
